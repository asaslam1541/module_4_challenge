# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
whale_returns_df = pd.read_csv(Path(r"C:\Users\5th gen\Dropbox\PC\Desktop\FinTech & Machine Learning Bootcamp\Challenges\Module_4_Challenge\Starter_Code\Resources\whale_returns.csv"))

# %%
algo_returns_df = pd.read_csv(r"C:\Users\5th gen\Dropbox\PC\Desktop\FinTech & Machine Learning Bootcamp\Challenges\Module_4_Challenge\Starter_Code\Resources\algo_returns.csv")

# %%
sp_tsx_history_df= pd.read_csv(r"C:\Users\5th gen\Dropbox\PC\Desktop\FinTech & Machine Learning Bootcamp\Challenges\Module_4_Challenge\Starter_Code\Resources\sp_tsx_history.csv")

# %%
# Convert the 'date' column to a DateTimeIndex
whale_returns_df['Date'] = pd.to_datetime(whale_returns_df['Date'])

# Set the 'date' column as the DataFrame's index
whale_returns_df.set_index('Date', inplace=True)

# %%
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Convert the 'date' column to a DateTimeIndex
algo_returns_df['Date'] = pd.to_datetime(algo_returns_df['Date'])

# Set the 'date' column as the DataFrame's index
algo_returns_df.set_index('Date', inplace=True)
# Print
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Convert to DateTimeIndex
sp_tsx_history_df["Date"] = pd.to_datetime(sp_tsx_history_df["Date"])

# Set index to 'Date'
sp_tsx_history_df.set_index("Date", inplace=True)

# Print
sp_tsx_history_df
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
# To identify null values
whale_returns_df.isnull()

# Remove rows wit null values
whale_returns_df.dropna(inplace=True)

# Remove columns with null values (in-place)
whale_returns_df.dropna(axis=1, inplace=True)

# Print
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
# To identify null values
algo_returns_df.isnull()

# Remove rows wit null values
algo_returns_df.dropna(inplace=True)

# Remove columns with null values (in-place)
algo_returns_df.dropna(axis=1, inplace=True)

# Print
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
# To identify null values
sp_tsx_history_df.isnull()

# Remove rows wit null values
sp_tsx_history_df.dropna(inplace=True)

# Remove columns with null values (in-place)
sp_tsx_history_df.dropna(axis=1, inplace=True)

# Print
sp_tsx_history_df
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
sp_tsx_history_df['Close'] = sp_tsx_history_df['Close'].str.replace('$', '')
# Out:
# C:\Users\5th gen\AppData\Local\Temp\ipykernel_6684\1255374437.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp_tsx_history_df['Close'] = sp_tsx_history_df['Close'].str.replace('$', '')

# %%
sp_tsx_history_df['Close'] = sp_tsx_history_df['Close'].str.replace(',', '')

# %%
sp_tsx_history_df
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99
# ...              ...
# 2019-12-20  17118.44
# 2019-12-23  17128.71
# 2019-12-24  17180.15
# 2019-12-27  17168.21
# 2019-12-30  17098.56
#
# [1818 rows x 1 columns]

# %%
# Convert 'Close' to numeric
sp_tsx_history_df['Close'] = pd.to_numeric(sp_tsx_history_df['Close'], errors='coerce')

# %%
sp_tsx_history_df
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99
# ...              ...
# 2019-12-20  17118.44
# 2019-12-23  17128.71
# 2019-12-24  17180.15
# 2019-12-27  17168.21
# 2019-12-30  17098.56
#
# [1818 rows x 1 columns]

# %%
tsx_daily_returns = sp_tsx_history_df.pct_change()

# %%
tsx_daily_returns.dropna()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %%
combined_df = pd.concat([whale_returns_df,algo_returns_df, tsx_daily_returns], axis='columns', join='inner')

# %%
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
# Rename the column from 'Close' to 'S&P TSX'
combined_df.rename(columns={'Close': 'S&P TSX'}, inplace=True)

# Print
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
# Calculate cumulative returns
cumulative_returns = (1 + combined_df).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(12, 6))
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.title('Cumulative Returns of Portfolios and S&P TSX 60')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create box plots for returns
combined_df.boxplot(figsize=(18, 12))
plt.title('Box Plots of Portfolio Returns')
plt.ylabel('Returns')
plt.grid(True)
plt.show()

# %%
# Calculate standard deviation
portfolio_std = combined_df.std()
tsx_std = combined_df['S&P TSX'].std()

# print results
print (portfolio_std)
print(tsx_std)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX                        0.007034
# dtype: float64
# 0.007034167748577725

# %%
# Determine portfolios riskier than S&P TSX 60
riskier_portfolios = portfolio_std[portfolio_std > tsx_std].index.tolist()

# Print result
print(riskier_portfolios)
# Out:
# ['SOROS FUND MANAGEMENT LLC', 'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1', 'Algo 2']

# %%
# Calculate annualized standard deviation
annualized_std = portfolio_std * (252 ** 0.5)

# %%
# Print results
print('Standard Deviation:')
print(portfolio_std)
print('\nPortfolios Riskier than S&P TSX 60:')
print(riskier_portfolios)
print('\nAnnualized Standard Deviation:')
print(annualized_std)
# Out:
# Standard Deviation:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX                        0.007034
# dtype: float64
#
# Portfolios Riskier than S&P TSX 60:
# ['SOROS FUND MANAGEMENT LLC', 'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1', 'Algo 2']
#
# Annualized Standard Deviation:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P TSX                        0.111664
# dtype: float64

# %%
# Calculate rolling standard deviation with a 21-day window
rolling_std = combined_df.rolling(window=21).std()

# %%
# Calculate correlation between each portfolio and S&P TSX 60
correlation_matrix = combined_df.corr()

# %%
# Choose one portfolio
chosen_portfolio = 'BERKSHIRE HATHAWAY INC'

# %%
# Calculate rolling beta between the chosen portfolio and S&P TSX 60 with a 60-day window
rolling_covariance = combined_df[chosen_portfolio].rolling(window=60).cov(combined_df['S&P TSX'])
rolling_variance = combined_df['S&P TSX'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance

# %%
# Plot rolling standard deviation
rolling_std.plot(figsize=(12, 6))
plt.xlabel('Date')
plt.ylabel('Rolling Standard Deviation')
plt.title('Rolling Standard Deviation of Portfolios and S&P TSX 60')
plt.legend()
plt.grid(True)
plt.show()

# Plot correlation matrix
import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Plot rolling beta
rolling_beta.plot(figsize=(12, 6))
plt.xlabel('Date')
plt.ylabel('Rolling Beta')
plt.title('Rolling Beta between ' + chosen_portfolio + ' and S&P TSX 60')
plt.grid(True)
plt.show()

# %%
# Calculate daily returns for risk-free rate (e.g., a 10-year government bond yield)
risk_free_rate = 0.01 / 252  # Replace with the appropriate risk-free rate

# Calculate the excess returns of portfolios over the risk-free rate
excess_returns = combined_df - risk_free_rate

# Calculate the annualized Sharpe ratio for each portfolio
sharpe_ratios = (excess_returns.mean() * 252) / (excess_returns.std() * (252 ** 0.5))

# %%
# Plot Sharpe ratios in a bar plot
plt.figure(figsize=(12, 6))
sharpe_ratios.plot(kind='bar', color='blue', alpha=0.7)
plt.xlabel('Portfolio')
plt.ylabel('Sharpe Ratio')
plt.title('Sharpe Ratios of Portfolios and S&P TSX 60')
plt.grid(axis='y')
plt.show()

# %%
# Now to create a custome portfolio with stock OTEX, L and SHOP.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Download and read data for individual stocks
otex_df = pd.read_csv(r'C:\Users\5th gen\Dropbox\PC\Desktop\FinTech & Machine Learning Bootcamp\Challenges\Module_4_Challenge\Starter_Code\Resources/otex_historical.csv', parse_dates=True, index_col='Date')
l_df = pd.read_csv(r'C:\Users\5th gen\Dropbox\PC\Desktop\FinTech & Machine Learning Bootcamp\Challenges\Module_4_Challenge\Starter_Code\Resources/l_historical.csv', parse_dates=True, index_col='Date')
shop_df = pd.read_csv(r'C:\Users\5th gen\Dropbox\PC\Desktop\FinTech & Machine Learning Bootcamp\Challenges\Module_4_Challenge\Starter_Code\Resources\shop_historical.csv', parse_dates=True, index_col='Date')

# %%
otex_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
l_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
shop_df.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
# Step 2: Calculate daily returns for each stock
otex_returns = otex_df['Close'].pct_change()
l_returns = l_df['Close'].pct_change()
shop_returns = shop_df['Close'].pct_change()

# %%
# Assuming an equal number of shares per stock
portfolio_returns = (otex_returns + l_returns + shop_returns) / 3

# %%
portfolio_returns.dropna()
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
#                 ...
# 2019-12-20    0.007495
# 2019-12-23   -0.006607
# 2019-12-24    0.006331
# 2019-12-27    0.007995
# 2019-12-30   -0.015737
# Name: Close, Length: 500, dtype: float64

# %%
# Step 4: Add your portfolio returns to the combined_df DataFrame
combined_df['My_Portfolio'] = portfolio_returns

# %%
# Calculate the annualized standard deviation
annualized_std = portfolio_returns.std() * (252 ** 0.5)

# %%
# Calculate and plot the rolling standard deviation with a 21-day window
rolling_std = portfolio_returns.rolling(window=21).std()
rolling_std.plot(figsize=(12, 6))
plt.xlabel('Date')
plt.ylabel('Rolling Standard Deviation')
plt.title('Rolling Standard Deviation of My Portfolio (21-Day Window)')
plt.grid(True)
plt.show()

# %%
# Calculate and plot the correlation
correlation_matrix = combined_df.corr()
plt.figure(figsize=(8, 6))
plt.matshow(correlation_matrix, cmap='coolwarm', fignum=1)
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation='vertical')
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.title('Correlation Matrix')
plt.show()

# Calculate beta for your portfolio compared to the S&P TSX 60
portfolio_covariance = portfolio_returns.cov(combined_df['S&P TSX'])
tsx_covariance = combined_df['S&P TSX'].cov(combined_df['S&P TSX'])
portfolio_beta = portfolio_covariance / tsx_covariance

# %%
# Calculate the Sharpe ratio
risk_free_rate = 0.01 / 252  # Replace with the appropriate risk-free rate
excess_portfolio_returns = portfolio_returns - risk_free_rate
sharpe_ratio = (excess_portfolio_returns.mean() * 252) / (excess_portfolio_returns.std() * (252 ** 0.5))

# Print results
print(f'Annualized Standard Deviation: {annualized_std}')
print(f'Portfolio Beta: {portfolio_beta}')
print(f'Sharpe Ratio: {sharpe_ratio}')

# Calculate and plot the Sharpe ratios
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * (252 ** 0.5))
sharpe_ratios.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Portfolio')
plt.ylabel('Sharpe Ratio')
plt.title('Sharpe Ratios of Portfolios')
plt.grid(axis='y')
plt.show()
# Out:
# Annualized Standard Deviation: 0.2167936807134586
# Portfolio Beta: 1.0330144435926856
# Sharpe Ratio: 1.5773739285069273
